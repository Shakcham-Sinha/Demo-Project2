# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakcham-Sinha/Demo-Project2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import required libreries

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Data folder/DATA.csv',na_values='=')
df
# Out:
#               State District   Market Commodity Variety Arrival_date  \
# 0    Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/3/2020
# 1    Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/4/2020
# 2    Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/6/2020
# 3    Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/7/2020
# 4    Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/10/2020
# ..              ...      ...      ...       ...     ...          ...
# 363    UttarPradesh     Agra  Achnera    Tomato   Other   12/16/2000
# 364    UttarPradesh     Agra  Achnera    Tomato   Other   12/21/2000
# 365    UttarPradesh     Agra  Achnera    Tomato   Other   12/23/2000
# 366    UttarPradesh     Agra  Achnera    Tomato   Other   12/25/2000
# 367    UttarPradesh     Agra  Achnera    Tomato   Other   12/30/2000
#
#      Min_price  Max_price  Modal_price
# 0           30         45           35
# 1           40         45           35
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         368 non-null    object
#  1   District      368 non-null    object
#  2   Market        368 non-null    object
#  3   Commodity     368 non-null    object
#  4   Variety       368 non-null    object
#  5   Arrival_date  368 non-null    object
#  6   Min_price     368 non-null    int64
#  7   Max_price     368 non-null    int64
#  8   Modal_price   368 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 26.0+ KB

# %%
df.isnull().sum()
# Out:
# State           0
# District        0
# Market          0
# Commodity       0
# Variety         0
# Arrival_date    0
# Min_price       0
# Max_price       0
# Modal_price     0
# dtype: int64

# %%
df.head(6)
# Out:
#             State District   Market Commodity Variety Arrival_date  Min_price  \
# 0  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/3/2020         30
# 1  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/4/2020         40
# 2  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/6/2020         35
# 3  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/7/2020         37
# 4  Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/10/2020         32
# 5  Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/11/2020         35
#
#    Max_price  Modal_price
# 0         45           35
# 1         45           35
# 2         45           35
# 3         45           35
# 4         45           35
# 5         45           35

# %%
df.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Variety', 'Arrival_date',
#        'Min_price', 'Max_price', 'Modal_price'],
#       dtype='object')

# %%
data2=df.copy()

# %%
#Replace null value with mean

# %%
data2=data2.dropna()

# %%
data2.head()
# Out:
#             State District   Market Commodity Variety Arrival_date  Min_price  \
# 0  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/3/2020         30
# 1  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/4/2020         40
# 2  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/6/2020         35
# 3  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/7/2020         37
# 4  Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/10/2020         32
#
#    Max_price  Modal_price
# 0         45           35
# 1         45           35
# 2         45           35
# 3         45           35
# 4         45           35

# %%
data2["Arrival_date"][28]
# Out:
# '1/12/2020'

# %%
str=data2["Arrival_date"][1]
str2=str.split('/')
print(str)
print(str2)
print(str2[0])
# Out:
# 1/4/2020
# ['1', '4', '2020']
# 1

# %%
Dict = {1: "January",2: "February",3: "March",4: "April",5: "May",6: "June",7: "July",8: "August",9: "September",10: "October",11: "November",12: "December"}
print(Dict)
# Out:
# {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

# %%
month_column=[]

# %%
for i in data2["Arrival_date"]:
  str=i
  str2=str.split('/')
  month_number = int(str2[1])
  month_name = Dict.get(month_number, "Unknown")
  month_column.append(month_name)

# %%
len(month_column)
# Out:
# 374

# %%
len(month_column)
# Out:
# 374

# %%
len(data2)
# Out:
# 368

# %%
month_column = month_column[:len(data2)]

# %%
len(month_column)
# Out:
# 368

# %%
len(data2)
# Out:
# 368

# %%
data2["month_column"]=month_column

# %%
data2["month_column"]
# Out:
# 0          March
# 1          April
# 2           June
# 3           July
# 4        October
#          ...
# 363      Unknown
# 364      January
# 365        March
# 366          May
# 367    September
# Name: month_column, Length: 368, dtype: object

# %%
data2["month_column"].unique()
# Out:
# array(['March', 'April', 'June', 'July', 'October', 'November', 'Unknown',
#        'February', 'May', 'August', 'September', 'December', 'January'],
#       dtype=object)

# %%
season_name=[]

# %%
for s in data2["month_column"]:
    if s in ["January", "February"]:
        season_name.append("Winter")
    elif s in ["March", "April"]:
        season_name.append("Spring")
    elif s in ["May", "June"]:
        season_name.append("Summer")
    elif s in ["July", "August"]:
        season_name.append("Monsoon")
    elif s in ["September", "October"]:
        season_name.append("Autumn")
    elif s in ["November", "December"]:
        season_name.append("Pre-Winter")

# %%
data2["season_name"]=season_name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-d8778bdf849e> in <cell line: 1>()
# ----> 1 data2["season_name"]=season_name
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4089         else:
#    4090             # set column
# -> 4091             self._set_item(key, value)
#    4092
#    4093     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4298         ensure homogeneity.
#    4299         """
# -> 4300         value, refs = self._sanitize_column(value)
#    4301
#    4302         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5037
#    5038         if is_list_like(value):
# ...

# %%
print(data2["month_column"].unique())
# Out:
# ['March' 'April' 'June' 'July' 'October' 'November' 'Unknown' 'February'
#  'May' 'August' 'September' 'December' 'January']

# %%
missing_values_count = 0
unexpected_values_count = 0

season_name = []

for s in data2["month_column"]:
    if pd.isna(s):
        season_name.append("Unknown")
        missing_values_count += 1
    elif s in ["January", "February"]:
        season_name.append("Winter")
    elif s in ["March", "April"]:
        season_name.append("Spring")
    elif s in ["May", "June"]:
        season_name.append("Summer")
    elif s in ["July", "August"]:
        season_name.append("Monsoon")
    elif s in ["September", "October"]:
        season_name.append("Autumn")
    elif s in ["November", "December"]:
        season_name.append("Pre-Winter")
    else:
        season_name.append("Unknown")
        unexpected_values_count += 1

data2["season"] = season_name

print(f"Missing values: {missing_values_count}")
print(f"Unexpected values: {unexpected_values_count}")
# Out:
# Missing values: 0
# Unexpected values: 152

# %%
# Initialize the season_name list
season_name = []

for s in data2["month_column"]:
    if pd.isna(s):
        season_name.append("Unknown")  # Handle missing (NaN) values
    elif s in ["January", "February"]:
        season_name.append("Winter")
    elif s in ["March", "April"]:
        season_name.append("Spring")
    elif s in ["May", "June"]:
        season_name.append("Summer")
    elif s in ["July", "August"]:
        season_name.append("Monsoon")
    elif s in ["September", "October"]:
        season_name.append("Autumn")
    elif s in ["November", "December"]:
        season_name.append("Pre-Winter")
    else:
        season_name.append("Unknown")  # Handle unexpected values

# Add the season_name list as a new column to your DataFrame
data2["season"] = season_name

# %%
print(len(season_name))
# Out:
# 368

# %%
print(len(data2))
# Out:
# 368

# %%
data2.head()
# Out:
#             State District   Market Commodity Variety Arrival_date  Min_price  \
# 0  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/3/2020         30
# 1  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/4/2020         40
# 2  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/6/2020         35
# 3  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/7/2020         37
# 4  Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/10/2020         32
#
#    Max_price  Modal_price month_column   season
# 0         45           35        March   Spring
# 1         45           35        April   Spring
# 2         45           35         June   Summer
# 3         45           35         July  Monsoon
# 4         45           35      October   Autumn

# %%
import pandas as pd
df=pd.Timestamp("1/3/2020")
print(df.dayofweek)
# Out:
# 4

# %%
day_of_week=[]

# %%
for i in data2["Arrival_date"]:
  str=i
  df=pd.Timestamp(i)
  day=df.dayofweek
  day_of_week.append(day)

# %%
len(day_of_week)
# Out:
# 368

# %%
data2["day"]=day_of_week

# %%
data2.tail()
# Out:
#             State District   Market Commodity Variety  Arrival_date  \
# 363  UttarPradesh     Agra  Achnera    Tomato   Other             5
# 364  UttarPradesh     Agra  Achnera    Tomato   Other             3
# 365  UttarPradesh     Agra  Achnera    Tomato   Other             5
# 366  UttarPradesh     Agra  Achnera    Tomato   Other             0
# 367  UttarPradesh     Agra  Achnera    Tomato   Other             5
#
#      Min_price  Max_price  Modal_price month_column   season  day
# 363         35         40           38      Unknown  Unknown    5
# 364         30         40           35      January   Winter    3
# 365         30         40           35        March   Spring    5
# 366         30         40           35          May   Summer    0
# 367         45         50           48    September   Autumn    5
