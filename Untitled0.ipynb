# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakcham-Sinha/Demo-Project2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import required libreries

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Data/DATACopy5.csv',na_values='=')
df
# Out:
#               State District   Market Commodity Variety Arrival_date  \
# 0    Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/3/2020
# 1    Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/4/2020
# 2    Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/6/2020
# 3    Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/7/2020
# 4    Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/10/2020
# ..              ...      ...      ...       ...     ...          ...
# 363    UttarPradesh     Agra  Achnera    Tomato   Other    12/1/2000
# 364    UttarPradesh     Agra  Achnera    Tomato   Other    12/2/2000
# 365    UttarPradesh     Agra  Achnera    Tomato   Other    12/3/2000
# 366    UttarPradesh     Agra  Achnera    Tomato   Other    12/5/2000
# 367    UttarPradesh     Agra  Achnera    Tomato   Other    12/3/2000
#
#      Min_price  Max_price  Modal_price
# 0           30         45           35
# 1           40         45           35
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         368 non-null    object
#  1   District      368 non-null    object
#  2   Market        368 non-null    object
#  3   Commodity     368 non-null    object
#  4   Variety       368 non-null    object
#  5   Arrival_date  368 non-null    object
#  6   Min_price     368 non-null    int64
#  7   Max_price     368 non-null    int64
#  8   Modal_price   368 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 26.0+ KB

# %%
df.isnull().sum()
# Out:
# State           0
# District        0
# Market          0
# Commodity       0
# Variety         0
# Arrival_date    0
# Min_price       0
# Max_price       0
# Modal_price     0
# dtype: int64

# %%
df.head(6)
# Out:
#             State District   Market Commodity Variety Arrival_date  Min_price  \
# 0  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/3/2020         30
# 1  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/4/2020         40
# 2  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/6/2020         35
# 3  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/7/2020         37
# 4  Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/10/2020         32
# 5  Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/11/2020         35
#
#    Max_price  Modal_price
# 0         45           35
# 1         45           35
# 2         45           35
# 3         45           35
# 4         45           35
# 5         45           35

# %%
df.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Variety', 'Arrival_date',
#        'Min_price', 'Max_price', 'Modal_price'],
#       dtype='object')

# %%
data1=df.copy()

# %%
#Replace null value with mean

# %%
data1=data1.dropna()

# %%
data1.head()
# Out:
#             State District   Market Commodity Variety Arrival_date  Min_price  \
# 0  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/3/2020         30
# 1  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/4/2020         40
# 2  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/6/2020         35
# 3  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/7/2020         37
# 4  Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/10/2020         32
#
#    Max_price  Modal_price
# 0         45           35
# 1         45           35
# 2         45           35
# 3         45           35
# 4         45           35

# %%
data1["Arrival_date"][28]
# Out:
# '1/12/2020'

# %%
str=data1["Arrival_date"][1]
str2=str.split('/')
print(str)
print(str2)
print(str2[0])
# Out:
# 1/4/2020
# ['1', '4', '2020']
# 1

# %%
Dict = {1: "January",2: "February",3: "March",4: "April",5: "May",6: "June",7: "July",8: "August",9: "September",10: "October",11: "November",12: "December"}
print(Dict)
# Out:
# {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

# %%
month_column=[]

# %%
for i in data1["Arrival_date"]:
  str=i
  str2=str.split('/')
  month_number = int(str2[1])
  month_name = Dict.get(month_number, "Unknown")
  month_column.append(month_name)

# %%
len(month_column)
# Out:
# 368

# %%
len(month_column)
# Out:
# 368

# %%
len(data1)
# Out:
# 368

# %%
month_column = month_column[:len(data1)]

# %%
len(month_column)
# Out:
# 368

# %%
len(data1)
# Out:
# 368

# %%
data1["month_column"]=month_column

# %%
data1["month_column"]
# Out:
# 0         March
# 1         April
# 2          June
# 3          July
# 4       October
#          ...
# 363     January
# 364    February
# 365       March
# 366         May
# 367       March
# Name: month_column, Length: 368, dtype: object

# %%
data1["month_column"].unique()
# Out:
# array(['March', 'April', 'June', 'July', 'October', 'November',
#        'December', 'January', 'August', 'February', 'May', 'September',
#        'Unknown'], dtype=object)

# %%
season_name=[]

# %%
for s in data1["month_column"]:
    if s in ["January", "February"]:
        season_name.append("Winter")
    elif s in ["March", "April"]:
        season_name.append("Spring")
    elif s in ["May", "June"]:
        season_name.append("Summer")
    elif s in ["July", "August"]:
        season_name.append("Monsoon")
    elif s in ["September", "October"]:
        season_name.append("Autumn")
    elif s in ["November", "December"]:
        season_name.append("Pre-Winter")

# %%
print(data1["month_column"].unique())
# Out:
# ['March' 'April' 'June' 'July' 'October' 'November' 'December' 'January'
#  'August' 'February' 'May' 'September' 'Unknown']

# %%
missing_values_count = 0
unexpected_values_count = 0

season_name = []

for s in data1["month_column"]:
    if pd.isna(s):
        season_name.append("Unknown")
        missing_values_count += 1
    elif s in ["January", "February"]:
        season_name.append("Winter")
    elif s in ["March", "April"]:
        season_name.append("Spring")
    elif s in ["May", "June"]:
        season_name.append("Summer")
    elif s in ["July", "August"]:
        season_name.append("Monsoon")
    elif s in ["September", "October"]:
        season_name.append("Autumn")
    elif s in ["November", "December"]:
        season_name.append("Pre-Winter")
    else:
        season_name.append("Unknown")
        unexpected_values_count += 1

data1["season"] = season_name

print(f"Missing values: {missing_values_count}")
print(f"Unexpected values: {unexpected_values_count}")
# Out:
# Missing values: 0
# Unexpected values: 2

# %%
# Initialize the season_name list
season_name = []

for s in data1["month_column"]:
    if pd.isna(s):
        season_name.append("Unknown")
    elif s in ["January", "February"]:
        season_name.append("Winter")
    elif s in ["March", "April"]:
        season_name.append("Spring")
    elif s in ["May", "June"]:
        season_name.append("Summer")
    elif s in ["July", "August"]:
        season_name.append("Monsoon")
    elif s in ["September", "October"]:
        season_name.append("Autumn")
    elif s in ["November", "December"]:
        season_name.append("Pre-Winter")
    else:
        season_name.append("Unknown")


data1["season"] = season_name

# %%
print(len(season_name))
# Out:
# 368

# %%
print(len(data1))
# Out:
# 368

# %%
data1.head()
# Out:
#             State District   Market Commodity Variety Arrival_date  Min_price  \
# 0  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/3/2020         30
# 1  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/4/2020         40
# 2  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/6/2020         35
# 3  Andhra Pradesh  Kurnool  Kurnool     Onion   Local     1/7/2020         37
# 4  Andhra Pradesh  Kurnool  Kurnool     Onion   Local    1/10/2020         32
#
#    Max_price  Modal_price month_column   season
# 0         45           35        March   Spring
# 1         45           35        April   Spring
# 2         45           35         June   Summer
# 3         45           35         July  Monsoon
# 4         45           35      October   Autumn

# %%
import pandas as pd
df=pd.Timestamp("1/3/2020")
print(df.dayofweek)
# Out:
# 4

# %%
day_of_week=[]

# %%
for i in data1["Arrival_date"]:
  str=i
  df=pd.Timestamp(i)
  day=df.dayofweek
  day_of_week.append(day)

# %%
len(day_of_week)
# Out:
# 368

# %%
data1["day"]=day_of_week

# %%
data1.tail()
# Out:
#             State District   Market Commodity Variety Arrival_date  Min_price  \
# 363  UttarPradesh     Agra  Achnera    Tomato   Other    12/1/2000         35
# 364  UttarPradesh     Agra  Achnera    Tomato   Other    12/2/2000         30
# 365  UttarPradesh     Agra  Achnera    Tomato   Other    12/3/2000         30
# 366  UttarPradesh     Agra  Achnera    Tomato   Other    12/5/2000         30
# 367  UttarPradesh     Agra  Achnera    Tomato   Other    12/3/2000         45
#
#      Max_price  Modal_price month_column  season  day
# 363         40           38      January  Winter    4
# 364         40           35     February  Winter    5
# 365         40           35        March  Spring    6
# 366         40           35          May  Summer    1
# 367         50           48        March  Spring    6

# %%
data1.drop('Arrival_date', axis=1, inplace=True)

# %%
data1.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Variety', 'Min_price',
#        'Max_price', 'Modal_price', 'month_column', 'season', 'day'],
#       dtype='object')

# %%
import seaborn as sns
sns.boxplot(data1['Modal_price'])
# Out:
# <Axes: ylabel='Modal_price'>

# %%
data1.shape
# Out:
# (368, 11)

# %%
data1['Modal_price']
# Out:
# 0      35
# 1      35
# 2      35
# 3      35
# 4      35
#        ..
# 363    38
# 364    35
# 365    35
# 366    35
# 367    48
# Name: Modal_price, Length: 368, dtype: int64

# %%
df=data1.copy()

# %%
import plotly.express as px

# %%
sns.relplot(data=df, x="State", y="Modal_price", hue="season", kind='line')

# %%
sns.relplot(data=df, x="District", y="Modal_price", hue="season", kind='line')

# %%
df.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Variety', 'Min_price',
#        'Max_price', 'Modal_price', 'month_column', 'season', 'day'],
#       dtype='object')

# %%
fig=px.bar(df,x="District",y="Modal_price",color="season",height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.relplot(data=df, x="season", y="Modal_price", hue="season", kind='line')

# %%
sns.relplot(data=df, x="day", y="Modal_price", hue="season", kind='line')

# %%
sns.relplot(data=df, x="Market", y="Modal_price", hue="season", kind='line')

# %%
sns.relplot(data=df, x="month_column", y="Modal_price", hue="season", kind='line')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         368 non-null    object
#  1   District      368 non-null    object
#  2   Market        368 non-null    object
#  3   Commodity     368 non-null    object
#  4   Variety       368 non-null    object
#  5   Min_price     368 non-null    int64
#  6   Max_price     368 non-null    int64
#  7   Modal_price   368 non-null    int64
#  8   month_column  368 non-null    object
#  9   season        368 non-null    object
#  10  day           368 non-null    int64
# dtypes: int64(4), object(7)
# memory usage: 31.8+ KB

# %%
dist=(data1['Commodity'])
distset=set(dist)
dd=list(distset)
dictOfWords={ dd[i]:i for i in range(0, len(dd)) }
data1['Commodity']=data1['Commodity'].map(dictOfWords)

# %%
dist=(data1['State'])
distset=set(dist)
dd=list(distset)
dictOfWords={ dd[i]:i for i in range(0, len(dd)) }
data1['State']=data1['State'].map(dictOfWords)

# %%
dist=(data1['District'])
distset=set(dist)
dd=list(distset)
dictOfWords={ dd[i]:i for i in range(0, len(dd)) }
data1['District']=data1['District'].map(dictOfWords)

# %%
dist=(data1['Market'])
distset=set(dist)
dd=list(distset)
dictOfWords={ dd[i]:i for i in range(0, len(dd)) }
data1['Market']=data1['Market'].map(dictOfWords)

# %%
dist=(data1['Variety'])
distset=set(dist)
dd=list(distset)
dictOfWords={ dd[i]:i for i in range(0, len(dd)) }
data1['Variety']=data1['Variety'].map(dictOfWords)

# %%
dist=(data1['month_column'])
distset=set(dist)
dd=list(distset)
dictOfWords={ dd[i]:i for i in range(0, len(dd)) }
data1['month_column']=data1['month_column'].map(dictOfWords)

# %%
dist=(data1['season'])
distset=set(dist)
dd=list(distset)
dictOfWords={ dd[i]:i for i in range(0, len(dd)) }
data1['season']=data1['season'].map(dictOfWords)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         368 non-null    int64
#  1   District      368 non-null    int64
#  2   Market        368 non-null    int64
#  3   Commodity     368 non-null    int64
#  4   Variety       368 non-null    int64
#  5   Min_price     368 non-null    int64
#  6   Max_price     368 non-null    int64
#  7   Modal_price   368 non-null    int64
#  8   month_column  368 non-null    int64
#  9   season        368 non-null    int64
#  10  day           368 non-null    int64
# dtypes: int64(11)
# memory usage: 31.8 KB

# %%
import matplotlib.pyplot as plt

# %%
dataplot=sns.heatmap(data1.corr(), cmap='YlGnBu',annot=True)
plt.show()

# %%
data1.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Variety', 'Min_price',
#        'Max_price', 'Modal_price', 'month_column', 'season', 'day'],
#       dtype='object')

# %%
features=data1[['State', 'District', 'Market', 'Commodity', 'Variety','month_column', 'season', 'day']]
labels=data1['Modal_price']

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(features,labels,test_size = 0.2,random_state=2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
regr= RandomForestRegressor(max_depth=1000,random_state=0)
regr.fit(Xtrain,Ytrain)
# Out:
# RandomForestRegressor(max_depth=1000, random_state=0)

# %%
Xtest[0:1]
# Out:
#     State  District  Market  Commodity  Variety  month_column  season  day
# 24     13         6       6          0        1            10       1    1

# %%
y_pred=regr.predict(Xtest)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Ytest, y_pred)
# Out:
# 0.6296058193482392

# %%
y_pred
# Out:
# array([50.        , 38.67666667, 35.8       , 40.112     , 35.272     ,
#        36.64333333, 41.6       , 42.1       , 41.92466667, 40.27      ,
#        39.64      , 38.40666667, 40.03      , 43.69833333, 42.02      ,
#        44.94666667, 44.42      , 50.        , 39.20666667, 36.08      ,
#        40.82      , 46.37      , 44.51      , 43.6115    , 50.        ,
#        43.57466667, 45.        , 47.225     , 47.4115    , 43.7       ,
#        50.        , 40.72      , 45.391     , 36.91      , 40.112     ,
#        39.13      , 45.42      , 45.        , 46.35166667, 47.57      ,
#        39.0675    , 37.255     , 40.49166667, 40.20866667, 46.1       ,
#        44.355     , 39.75133333, 43.50166667, 44.82      , 45.27      ,
#        50.        , 50.        , 43.92      , 36.902     , 45.11      ,
#        35.78      , 45.05      , 34.33      , 36.28333333, 44.84      ,
#        42.96      , 37.12      , 43.86      , 44.455     , 40.9365    ,
# ...

# %%
data1.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Variety', 'Min_price',
#        'Max_price', 'Modal_price', 'month_column', 'season', 'day'],
#       dtype='object')

# %%
Xtest[0:1]
# Out:
#     State  District  Market  Commodity  Variety  month_column  season  day
# 24     13         6       6          0        1            10       1    1

# %%
user_input=[[13,6,6,0,1,10,1,1]]
regr.predict(user_input)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names
# array([50.])
